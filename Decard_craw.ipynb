# %%
#透過Python取得該頁資料
#使用requests套件的requests.get()方法
import requests
url = 'https://www.dcard.tw/f'
resp = requests.get(url) #回傳為一個request.Response的物件
print(resp.status_code)
html=requests.get(url).text
soup=BeautifulSoup(html,'html.parser')
print(soup)
# Out:
# 200
# <!DOCTYPE html>
# ...

# %%
items=soup.select('.tgn9uw-2')
i=0
item_desc = []
itemurl = []

baseurl = 'https://www.dcard.tw'
for item in items:
    item_desc = soup.select(".tgn9uw-2 a span")[i].text.strip()#店名、地址
    itemurl = item.select('.tgn9uw-2 a')[0]['href']
    newurl = baseurl + itemurl
    print(item_desc)
    print(newurl)
    i+=1
# Out:
# nanaq在哪裡～？（我食言了再更！）
# https://www.dcard.tw/f/youtuber/p/236458231
# 讓男友ig的大奶妹全消失
# https://www.dcard.tw/f/relationship/p/236461811
# 女友用金錢交易來偷吃… #情愛偵探事件簿
# https://www.dcard.tw/f/relationship/p/236457763
# 如果你被家暴，你知道該怎麼做嗎？
# https://www.dcard.tw/f/talk/p/236461866
# 66kg減到48kg 小小分享
# https://www.dcard.tw/f/weight_loss/p/236458255
# 8年の顏值進化史：好皮膚的重要性
# https://www.dcard.tw/f/makeup/p/236460781
# #分享 五毛孔聯通的洞洞（毛孔彈性無極限😱）
# https://www.dcard.tw/f/makeup/p/236458379
# 姐 妳知道我⋯
# https://www.dcard.tw/f/mood/p/236458444
# 林安妹妹你什麼時候才能清醒
# https://www.dcard.tw/f/funny/p/236457972
# 瘦身歷程小分享2015-2019-現在
# https://www.dcard.tw/f/weight_loss/p/236461116
# 哥哥的腿與妹妹的腿
# https://www.dcard.tw/f/funny/p/236458533
# 無法接受小編這麼沒禮貌..
# https://www.dcard.tw/f/talk/p/236458098
# #圖～屈臣氏買什麼🥺🥲
# https://www.dcard.tw/f/makeup/p/236457262
# 女孩們，穿好內衣真的很重要！
# https://www.dcard.tw/f/girl/p/236460851
# 三年前就見識過這個小編了
# https://www.dcard.tw/f/talk/p/236457833
# 這些我完全不討厭的YouTuber
# ...

# %%
print(i)
# Out:
# 30

# %%
from flask import Flask, request, abort,make_response,jsonify

from linebot import ( 
    LineBotApi, WebhookHandler
)
from linebot.exceptions import ( 
    InvalidSignatureError
)
from linebot.models import ( 
    MessageEvent, TextMessage, TextSendMessage,QuickReply,
    QuickReplyButton,MessageAction,CameraAction,CameraRollAction,
    LocationAction,FlexSendMessage,LocationMessage,TemplateSendMessage,
    CarouselTemplate,CarouselColumn,PostbackTemplateAction,MessageTemplateAction,
    URITemplateAction,ButtonsTemplate,PostbackAction,URIAction,ConfirmTemplate
)

# %%
app = Flask(__name__)

line_bot_api = LineBotApi('channel access token')
handler = WebhookHandler('channel secret')


#網站系統IP
webhookURL = 'https://995b539b8b56.ngrok.io'

# %%
@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value #????
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'

# %%
@handler.add(MessageEvent, message=TextMessage)
def dcard_recommend(event):
    user_id = event.source.user_id
    print(user_id)
    if event.message.text == '我想看熱門貼文':
        
        response = '為您推薦:\n' + '===============' + '\n'
        #craw the articles
        items=soup.select('.tgn9uw-2')
        i=0
        item_desc = []
        itemurl = []

        baseurl = 'https://www.dcard.tw'
        for item in items:
            itemtitle = soup.select(".tgn9uw-2 a span")[i].text.strip()#店名、地址
            itemurl = item.select('.tgn9uw-2 a')[0]['href']
            newurl = baseurl + itemurl
            response = response + str(i+1) + '.' + itemtitle + '\n' + newurl + '\n' + '===============' + '\n'
            print(itemtitle)
            print(newurl)
            i+=1
        
        line_bot_api.push_message(
            user_id,
            TextSendMessage(text=response)
        )

# %%
"""
@handler.add(MessageEvent, message=TextMessage)
def echo(event):
    line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text=event.message.text)
    )
"""
# Out:
# '\n@handler.add(MessageEvent, message=TextMessage)\ndef echo(event):\n    line_bot_api.reply_message(\n        event.reply_token,\n        TextSendMessage(text=event.message.text)\n    )\n'

# %%
if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# Ub266ed4a3feeae039222916f7e6636fc
# nanaq在哪裡～？（我食言了再更！）
# https://www.dcard.tw/f/youtuber/p/236458231
# 讓男友ig的大奶妹全消失
# https://www.dcard.tw/f/relationship/p/236461811
# 女友用金錢交易來偷吃… #情愛偵探事件簿
# https://www.dcard.tw/f/relationship/p/236457763
# 如果你被家暴，你知道該怎麼做嗎？
# https://www.dcard.tw/f/talk/p/236461866
# 66kg減到48kg 小小分享
# https://www.dcard.tw/f/weight_loss/p/236458255
# 8年の顏值進化史：好皮膚的重要性
# https://www.dcard.tw/f/makeup/p/236460781
# #分享 五毛孔聯通的洞洞（毛孔彈性無極限😱）
# https://www.dcard.tw/f/makeup/p/236458379
# 姐 妳知道我⋯
# https://www.dcard.tw/f/mood/p/236458444
# 林安妹妹你什麼時候才能清醒
# https://www.dcard.tw/f/funny/p/236457972
# 瘦身歷程小分享2015-2019-現在
# https://www.dcard.tw/f/weight_loss/p/236461116
# 哥哥的腿與妹妹的腿
# ...
